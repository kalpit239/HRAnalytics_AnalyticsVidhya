# %% [markdown]
# # Code 5
# - Combine all Strategy
#   - Missing Value Imputation
#   - Outlier Startegy
#   - Tranformation Strategy

# %% [markdown]
# ## 1/ Import Libraries

# %%
#CodeSection1
from google.colab import drive
drive.mount('/mntDrive')
# Out:
# Drive already mounted at /mntDrive; to attempt to forcibly remount, call drive.mount("/mntDrive", force_remount=True).

# %%
#CodeSection2
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2/ Import Data

# %%
#CodeSection3
train = pd.read_csv('/mntDrive/MyDrive/__Data_Science/3 HR Analytics/input/train.csv')
test = pd.read_csv('/mntDrive/MyDrive/__Data_Science/3 HR Analytics/input/test.csv')

# %% [markdown]
# ## 3/ Combine both Datasets (train, test)

# %%
#CodeSection4
all_data = [train, test]

# %% [markdown]
# ### Check Combined Data
# - Missing Value
# - Data Types

# %%
#CodeSection5
# Combine both to check Missing Value
pd.concat([train, test], axis = 0).isnull().sum()
# Out:
# enrollee_id                   0
# city                          0
# city_development_index        0
# gender                     7486
# relevent_experience           0
# enrolled_university         621
# education_level             852
# major_discipline           5231
# experience                  103
# company_size               8830
# company_type               9369
# last_new_job                671
# training_hours                0
# target                    15021
# dtype: int64

# %%
#CodeSection6
# Check Data types for each variable
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18359 entries, 0 to 18358
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             18359 non-null  int64
#  1   city                    18359 non-null  object
#  2   city_development_index  18359 non-null  float64
#  3   gender                  14261 non-null  object
#  4   relevent_experience     18359 non-null  object
#  5   enrolled_university     18017 non-null  object
#  6   education_level         17902 non-null  object
#  7   major_discipline        15521 non-null  object
#  8   experience              18300 non-null  object
#  9   company_size            13580 non-null  object
#  10  company_type            13320 non-null  object
#  11  last_new_job            17992 non-null  object
#  12  training_hours          18359 non-null  int64
#  13  target                  18359 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 2.0+ MB

# %% [markdown]
# ## 4/ Numerical Processing

# %% [markdown]
# ### 4.1/ Impute Numerical Variables

# %%
#CodeSection7
# Identify all Numerical features
numerical = ['city_development_index', 'training_hours']

# %%
#CodeSection8
# Import SimpleImputer
from sklearn.impute import SimpleImputer

# %%
#CodeSection9

#Initiate SimpleImputer
num_impute = SimpleImputer(strategy = 'median')


# Fit SimpleImputer on Numerical Features
num_impute.fit(train[numerical])
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='median', verbose=0)

# %%
#CodeSection10
# Impute Train and Test
for dataset in all_data:
  dataset[numerical] = num_impute.transform(dataset[numerical])

# %% [markdown]
# ### 4.2/ Outlier Strategy

# %%
#CodeSection11

# Write a loop to detect and impute Outliers
for num_var in numerical:
  Q1 = train[num_var].quantile(0.25)
  Q3 = train[num_var].quantile(0.75)

  IQR = Q3-Q1

  Lower_Whisker = Q1 - 1.5*IQR
  Upper_Whisker = Q3 + 1.5*IQR

  for dataset in all_data:
    dataset[num_var] = dataset[num_var].apply(lambda x : Upper_Whisker if x > Upper_Whisker else x)
    dataset[num_var] = dataset[num_var].apply(lambda x : Lower_Whisker if x > Lower_Whisker else x)

# %% [markdown]
# ### 4.3/ Transformation Strategy

# %%
#CodeSection12
# Import StandardScaler
from sklearn.preprocessing import StandardScaler

# %%
#CodeSection13

#Initiate StandardScaler
num_scale = StandardScaler()

# Fit StandardScaler
num_scale.fit(train[numerical])
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
#CodeSection14
# Scale Train and Test
for dataset in all_data:
  dataset[numerical] = num_scale.transform(dataset[numerical])

# %% [markdown]
# ## 5/ Impute Categorical Variables

# %% [markdown]
# ### Impute all Categorical Variables at once

# %%
#CodeSection15
# Identify all Categorical Features
categorical = ['gender','relevent_experience','enrolled_university','education_level','major_discipline','experience','company_size','company_type', 'last_new_job']

# %%
#CodeSection16
# Import SimpleImputer
cat_impute = SimpleImputer(strategy = 'most_frequent')
cat_impute.fit(train[categorical])
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='most_frequent', verbose=0)

# %%
#CodeSection17

#Initiate SimpleImputer
cat_impute = SimpleImputer(strategy = 'most_frequent')
cat_impute.fit(train[categorical])
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='most_frequent', verbose=0)

# %%
#CodeSection18
# Impute Train and Test
for dataset in all_data:
  dataset[categorical] = cat_impute.transform(dataset[categorical])

# %% [markdown]
# ## 6/ Now Re Check all Features

# %%
#CodeSection19
# Combine both to check Missing Value
pd.concat([train, test], axis = 0).isnull().sum()
# Out:
# enrollee_id                   0
# city                          0
# city_development_index        0
# gender                        0
# relevent_experience           0
# enrolled_university           0
# education_level               0
# major_discipline              0
# experience                    0
# company_size                  0
# company_type                  0
# last_new_job                  0
# training_hours                0
# target                    15021
# dtype: int64

# %% [markdown]
# ## 8/ Prepare Data for Model Model

# %%
train.head()
# Out:
#    enrollee_id      city  ...  training_hours target
# 0        23798  city_149  ...             0.0      0
# 1        29166   city_83  ...             0.0      0
# 2           46   city_16  ...             0.0      0
# 3        18527   city_64  ...             0.0      0
# 4        21751  city_100  ...             0.0      1
#
# [5 rows x 14 columns]

# %%
#CodeSection20
# Check First 5 Rows of Test Data
test.head()
# Out:
#    enrollee_id      city  ...  last_new_job training_hours
# 0        16548   city_33  ...             1            0.0
# 1        12036   city_28  ...             1            0.0
# 2        11061  city_103  ...             1            0.0
# 3         5032  city_104  ...             2            0.0
# 4        17599   city_77  ...             2            0.0
#
# [5 rows x 13 columns]

# %%
#CodeSection21
# Get X and y Variables for your Dataset
X = train.drop(['target','enrollee_id'], axis =  1)
y = train['target']

# %% [markdown]
# ### Create Dummy Variables for  Categorical Variables

# %%
#CodeSection22
# Get Dummy Variables
X = pd.get_dummies(X, drop_first = True)  # Keep only n - 1 Variables - Use "drop_first = True"

# %% [markdown]
# ## 9/ Build Model

# %%
#CodeSection23
#Import Logistic Regression Library
from sklearn.linear_model import LogisticRegression

#Initialize LR
clf = LogisticRegression(max_iter = 1000, class_weight = 'balanced')

# %%
#CodeSection24
# Fit Model
model = clf.fit(X, y)

# %% [markdown]
# ### Check Accuracy of Model on Train Data

# %%
#CodeSection25
# Predict on Train Data
y_pred = model.predict(X)

# %% [markdown]
# ### We can use a Accuracy Function from Metrics
# - Check Train Accuracy

# %%
#CodeSection26
# Import metrics library
from sklearn.metrics import accuracy_score

# %%
#CodeSection27
# get Actual "y" variables (use "y_true" as variable)
y_true = y

# %%
#CodeSection28
# Print Train Accuracy
print(f" Train Accuracy : {accuracy_score(y_true, y_pred):0.1%}")
# Out:
#  Train Accuracy : 66.7%

# %% [markdown]
# ## 10/ Predict and Submit

# %% [markdown]
# ### Predict

# %%
#CodeSection29
# Get all the X Variables from the Test Dataset
X_test = test.drop(['enrollee_id'], axis =  1)

# %%
#CodeSection30
#Covert to Dummies
X_test = pd.get_dummies(X_test, drop_first = True)

# %%
#CodeSection31
# use this code if the next Code shows error
#X_test['Married_Missing']  = 0

# %%
#CodeSection32
# Predict on X_test Data ("X_test_prep")
X_test_prep = model.predict(X_test)

# %% [markdown]
# ### Create Submission File

# %%
#CodeSection33
submission = pd.DataFrame({
    'enrollee_id' : test['enrollee_id'],
    'target' : X_test_prep
})

# %% [markdown]
# ### Export Submission File

# %%
#CodeSection34
submission.to_csv('/mntDrive/MyDrive/__Data_Science/3 HR Analytics/output/O5_Preproccesing_All.csv', index = False)

# %%
# LB Accuracy : 0.7777
